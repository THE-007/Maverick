# %%
import pandas as pd
import csv

DF = pd.read_csv("defuzzy_csv/Clubs_data.csv")
DF

# %%
NamesDictionary = {"name":[],"id":[],"Club":[]}
with open("Metadata.csv") as csvreader:
    csvpointer = csv.reader(csvreader)
    next(csvreader)
    for lines in csvpointer:
        NamesDictionary["name"].append(lines[0])
        NamesDictionary["id"].append(lines[1])
print(NamesDictionary["name"][0])
print(NamesDictionary["id"][0])

# %%
with open("defuzzy_csv/Clubs_data.csv") as csvreader:
    csvpointer = csv.reader(csvreader)
    i = 0
    for lines in csvpointer:
        NamesDictionary["Club"].append(lines[2])
        i=i+1

# %%
print(NamesDictionary)

# %%
Clubsdata = []
array = [[0]*3]*3
print(array)

Clubsdata.append(array)
print(Clubsdata)

# %%
list = []
list.append("name")
list.append("id")
for
